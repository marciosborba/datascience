# %% [markdown]
# # Mapa Eleitora de 2 Turno do Estado de SC para Governador

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
# %matplotlib inline

# %%
df_mapsc = gpd.read_file(r'C:\Users\Marcio\Desktop\Data Science\Mapas IBGE\BRMUE250GC_SIR.shp')

df_mapsc.head()
# Out:
#                    NM_MUNICIP CD_GEOCMU  \
# 0                      CAIUÃ   3509106
# 1                    CASTILHO   3511003
# 2                     DRACENA   3514403
# 3            ESTRELA DO NORTE   3515301
# 4  EUCLIDES DA CUNHA PAULISTA   3515350
#
#                                             geometry
# 0  POLYGON ((-51.86001052999998 -21.5807199056459...
# 1  POLYGON ((-51.41936432700003 -20.6810765586240...
# 2  POLYGON ((-51.48515406800003 -21.4276462056422...
# 3  POLYGON ((-51.57097467399996 -22.3988718766653...
# 4  POLYGON ((-52.44569233499996 -22.6082794076701...

# %%
df_mapsc.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 3 columns):
# NM_MUNICIP    5572 non-null object
# CD_GEOCMU     5572 non-null object
# geometry      5572 non-null object
# dtypes: object(3)
# memory usage: 130.7+ KB

# %%
df_mapsc.plot()

# %%
df_votosc = pd.read_csv('votacao_candidato_munzona_2018_SC.csv', sep=';', encoding='latin1')

df_votosc.head().T
# Out:
#                                                        0  \
# DT_GERACAO                                    24/09/2019
# HH_GERACAO                                      19:36:33
# ANO_ELEICAO                                         2018
# CD_TIPO_ELEICAO                                        2
# NM_TIPO_ELEICAO                        Eleição Ordinária
# NR_TURNO                                               1
# CD_ELEICAO                                           297
# DS_ELEICAO                ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                    07/10/2018
# TP_ABRANGENCIA                                         E
# SG_UF                                                 SC
# SG_UE                                                 SC
# NM_UE                                     SANTA CATARINA
# CD_MUNICIPIO                                       81205
# NM_MUNICIPIO                             SANTIAGO DO SUL
# NR_ZONA                                               78
# CD_CARGO                                               6
# DS_CARGO                                Deputado Federal
# SQ_CANDIDATO                                240000627218
# NR_CANDIDATO                                        4343
# NM_CANDIDATO                      GUARACI EDSON FAGUNDES
# NM_URNA_CANDIDATO                       GUARACI FAGUNDES
# NM_SOCIAL_CANDIDATO                               #NULO#
# CD_SITUACAO_CANDIDATURA                               12
# DS_SITUACAO_CANDIDATURA                             APTO
# CD_DETALHE_SITUACAO_CAND                               2
# DS_DETALHE_SITUACAO_CAND                        DEFERIDO
# TP_AGREMIACAO                                  Coligação
# NR_PARTIDO                                            43
# SG_PARTIDO                                            PV
# NM_PARTIDO                                 Partido Verde
# SQ_COLIGACAO                                240000050741
# NM_COLIGACAO                                   PSD/PP/PV
# DS_COMPOSICAO_COLIGACAO                    PSD / PP / PV
# CD_SIT_TOT_TURNO                                       5
# DS_SIT_TOT_TURNO                                SUPLENTE
# ST_VOTO_EM_TRANSITO                                    N
# QT_VOTOS_NOMINAIS                                      0
#
#                                                                 1  \
# DT_GERACAO                                             24/09/2019
# HH_GERACAO                                               19:36:33
# ANO_ELEICAO                                                  2018
# CD_TIPO_ELEICAO                                                 2
# NM_TIPO_ELEICAO                                 Eleição Ordinária
# NR_TURNO                                                        1
# CD_ELEICAO                                                    297
# DS_ELEICAO                         ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                             07/10/2018
# TP_ABRANGENCIA                                                  E
# SG_UF                                                          SC
# SG_UE                                                          SC
# NM_UE                                              SANTA CATARINA
# CD_MUNICIPIO                                                80721
# NM_MUNICIPIO                                         SANTA HELENA
# NR_ZONA                                                        45
# CD_CARGO                                                        6
# DS_CARGO                                         Deputado Federal
# SQ_CANDIDATO                                         240000609634
# NR_CANDIDATO                                                 4545
# NM_CANDIDATO                                MARCO ANTONIO TEBALDI
# NM_URNA_CANDIDATO                                   MARCO TEBALDI
# NM_SOCIAL_CANDIDATO                                        #NULO#
# CD_SITUACAO_CANDIDATURA                                        12
# DS_SITUACAO_CANDIDATURA                                      APTO
# CD_DETALHE_SITUACAO_CAND                                        2
# DS_DETALHE_SITUACAO_CAND                                 DEFERIDO
# TP_AGREMIACAO                                           Coligação
# NR_PARTIDO                                                     45
# SG_PARTIDO                                                   PSDB
# NM_PARTIDO                Partido da Social Democracia Brasileira
# SQ_COLIGACAO                                         240000050252
# NM_COLIGACAO                            SANTA CATARINA MAIS FORTE
# DS_COMPOSICAO_COLIGACAO                     PSDB / PPS / PTB / DC
# CD_SIT_TOT_TURNO                                                5
# DS_SIT_TOT_TURNO                                         SUPLENTE
# ST_VOTO_EM_TRANSITO                                             N
# QT_VOTOS_NOMINAIS                                             135
#
#                                                          2  \
# DT_GERACAO                                      24/09/2019
# HH_GERACAO                                        19:36:33
# ANO_ELEICAO                                           2018
# CD_TIPO_ELEICAO                                          2
# NM_TIPO_ELEICAO                          Eleição Ordinária
# NR_TURNO                                                 1
# CD_ELEICAO                                             297
# DS_ELEICAO                  ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                      07/10/2018
# TP_ABRANGENCIA                                           E
# SG_UF                                                   SC
# SG_UE                                                   SC
# NM_UE                                       SANTA CATARINA
# CD_MUNICIPIO                                         83470
# NM_MUNICIPIO                                   SIDERÓPOLIS
# NR_ZONA                                                 92
# CD_CARGO                                                 7
# DS_CARGO                                 Deputado Estadual
# SQ_CANDIDATO                                  240000609575
# NR_CANDIDATO                                         15220
# NM_CANDIDATO                                MAURO DE NADAL
# NM_URNA_CANDIDATO                                 DE NADAL
# NM_SOCIAL_CANDIDATO                                 #NULO#
# CD_SITUACAO_CANDIDATURA                                 12
# DS_SITUACAO_CANDIDATURA                               APTO
# CD_DETALHE_SITUACAO_CAND                                 2
# DS_DETALHE_SITUACAO_CAND                          DEFERIDO
# TP_AGREMIACAO                                    Coligação
# NR_PARTIDO                                              15
# SG_PARTIDO                                             MDB
# NM_PARTIDO                Movimento Democrático Brasileiro
# SQ_COLIGACAO                                  240000050251
# NM_COLIGACAO                       MAIS POR SANTA CATARINA
# DS_COMPOSICAO_COLIGACAO                         MDB / PSDB
# CD_SIT_TOT_TURNO                                         2
# DS_SIT_TOT_TURNO                             ELEITO POR QP
# ST_VOTO_EM_TRANSITO                                      N
# QT_VOTOS_NOMINAIS                                        0
#
#                                                        3  \
# DT_GERACAO                                    24/09/2019
# HH_GERACAO                                      19:36:33
# ANO_ELEICAO                                         2018
# CD_TIPO_ELEICAO                                        2
# NM_TIPO_ELEICAO                        Eleição Ordinária
# NR_TURNO                                               1
# CD_ELEICAO                                           297
# DS_ELEICAO                ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                    07/10/2018
# TP_ABRANGENCIA                                         E
# SG_UF                                                 SC
# SG_UE                                                 SC
# NM_UE                                     SANTA CATARINA
# CD_MUNICIPIO                                       81051
# NM_MUNICIPIO                               FLORIANÓPOLIS
# NR_ZONA                                               13
# CD_CARGO                                               7
# DS_CARGO                               Deputado Estadual
# SQ_CANDIDATO                                240000619070
# NR_CANDIDATO                                       40555
# NM_CANDIDATO                         RAQUEL RONISE ALVES
# NM_URNA_CANDIDATO                         RAQUEL PECATTO
# NM_SOCIAL_CANDIDATO                               #NULO#
# CD_SITUACAO_CANDIDATURA                               12
# DS_SITUACAO_CANDIDATURA                             APTO
# CD_DETALHE_SITUACAO_CAND                               2
# DS_DETALHE_SITUACAO_CAND                        DEFERIDO
# TP_AGREMIACAO                                  Coligação
# NR_PARTIDO                                            40
# SG_PARTIDO                                           PSB
# NM_PARTIDO                 Partido Socialista Brasileiro
# SQ_COLIGACAO                                240000050494
# NM_COLIGACAO                   PSB - PRB - SOLIDARIEDADE
# DS_COMPOSICAO_COLIGACAO        PSB / PRB / SOLIDARIEDADE
# CD_SIT_TOT_TURNO                                       5
# DS_SIT_TOT_TURNO                                SUPLENTE
# ST_VOTO_EM_TRANSITO                                    N
# QT_VOTOS_NOMINAIS                                     55
#
#                                                        4
# DT_GERACAO                                    24/09/2019
# HH_GERACAO                                      19:36:33
# ANO_ELEICAO                                         2018
# CD_TIPO_ELEICAO                                        2
# NM_TIPO_ELEICAO                        Eleição Ordinária
# NR_TURNO                                               1
# CD_ELEICAO                                           297
# DS_ELEICAO                ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                    07/10/2018
# TP_ABRANGENCIA                                         E
# SG_UF                                                 SC
# SG_UE                                                 SC
# NM_UE                                     SANTA CATARINA
# CD_MUNICIPIO                                
# 3828                   4       NÃO ELEITO                    N
# 3831                   4       NÃO ELEITO                    N
# 3843                   4       NÃO ELEITO                    N
# 4276                   1           ELEITO                    N
# 4290                   1           ELEITO                    N
# 4292                   1           ELEITO                    N
# 6114                   1           ELEITO                    N
# 6115                   1           ELEITO                    N
# 6128                   1           ELEITO                    N
# 6138                   1           ELEITO                    N
# 7233                   4       NÃO ELEITO                    N
# 7734                   4       NÃO ELEITO                    N
# 7735                   4       NÃO ELEITO                    N
# 7739                   4       NÃO ELEITO                    N
# 7740                   4       NÃO ELEITO                    N
# 7758                   4       NÃO ELEITO                    N
# ...                  ...              ...                  ...
# 206143                 1           ELEITO                    N
# 206431                 4       NÃO ELEITO                    N
# 206873                 4       NÃO ELEITO                    N
# 207584                 1           ELEITO                    N
# 209189                 1           ELEITO                    N
# 210551                 1           ELEITO                    N
# 210596                 1           ELEITO                    N
# 211373                 1           ELEITO                    N
# 211908                 1           ELEITO                    N
# 211909                 1           ELEITO                    N
# 211924                 4       NÃO ELEITO                    N
# 212310                 1           ELEITO                    N
# 213117                 1           ELEITO                    N
# 213616                 4       NÃO ELEITO                    N
# 213846                 1           ELEITO                    N
# 213977                 1           ELEITO                    N
# 214314                 1           ELEITO                    N
# 214565                 4       NÃO ELEITO                    N
# 214743                 4       NÃO ELEITO                    N
# 214749                 4       NÃO ELEITO                    N
# 214914                 4       NÃO ELEITO                    N
# 215061                 4       NÃO ELEITO                    N
# 215746                 1           ELEITO                    N
# 216009                 1           ELEITO                    N
# 216877                 4       NÃO ELEITO                    N
# 217148                 1           ELEITO                    N
# 217428                 1           ELEITO                    N
# 217569                 1           ELEITO                    N
# 218878                 1           ELEITO                    N
# 219601                 4       NÃO ELEITO                    N
#
#         QT_VOTOS_NOMINAIS
# 131                   863
# 180                  2075
# 182                  2320
# 220                  1311
# 1541                 9383
# 1797                 7423
# 1805                 1594
# 1819                 2999
# 1820                  506
# 1999                 1975
# 2898                 2311
# 3166                 3105
# 3181                  865
# 3286                 1635
# 3828                 1353
# 3831                26232
# 3843                 3088
# 4276                16758
# 4290                36104
# 4292                 2752
# 6114                 8296
# 6115                 1230
# 6128                  800
# 6138                11019
# 7233                 3044
# 7734                 1264
# 7735                 1879
# 7739                 5259
# 7740                  812
# 7758                  841
# ...                   ...
# 206143               3361
# 206431               1672
# 206873               1316
# 207584                883
# 209189               9552
# 210551                952
# 210596               1382
# 211373               1731
# 211908               5751
# 211909              26203
# 211924               1708
# 212310              45728
# 213117               2901
# 213616               1180
# 213846                659
# 213977               2567
# 214314                630
# 214565                655
# 214743               1177
# 214749                803
# 214914               9161
# 215061               1027
# 215746               7658
# 216009                778
# 216877               1799
# 217148                984
# 217428               2366
# 217569               6455
# 218878               3419
# 219601               9109
#
# [628 rows x 38 columns]

# %%
df_votosc = df_votosc[df_votosc['NR_TURNO']==2]

# %%
df_votosc.head().T
# Out:
#                                                     131   \
# DT_GERACAO                                    24/09/2019
# HH_GERACAO                                      19:36:33
# ANO_ELEICAO                                         2018
# CD_TIPO_ELEICAO                                        2
# NM_TIPO_ELEICAO                        Eleição Ordinária
# NR_TURNO                                               2
# CD_ELEICAO                                           298
# DS_ELEICAO                ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                    28/10/2018
# TP_ABRANGENCIA                                         E
# SG_UF                                                 SC
# SG_UE                                                 SC
# NM_UE                                     SANTA CATARINA
# CD_MUNICIPIO                                       82066
# NM_MUNICIPIO                                      MAREMA
# NR_ZONA                                               48
# CD_CARGO                                               3
# DS_CARGO                                      Governador
# SQ_CANDIDATO                                240000609724
# NR_CANDIDATO                                          17
# NM_CANDIDATO                      CARLOS MOISÉS DA SILVA
# NM_URNA_CANDIDATO                      COMANDANTE MOISÉS
# NM_SOCIAL_CANDIDATO                               #NULO#
# CD_SITUACAO_CANDIDATURA                               12
# DS_SITUACAO_CANDIDATURA                             APTO
# CD_DETALHE_SITUACAO_CAND                               2
# DS_DETALHE_SITUACAO_CAND                        DEFERIDO
# TP_AGREMIACAO                            Partido isolado
# NR_PARTIDO                                            17
# SG_PARTIDO                                           PSL
# NM_PARTIDO                        Partido Social Liberal
# SQ_COLIGACAO                                240000050254
# NM_COLIGACAO                             PARTIDO ISOLADO
# DS_COMPOSICAO_COLIGACAO                              PSL
# CD_SIT_TOT_TURNO                                       1
# DS_SIT_TOT_TURNO                                  ELEITO
# ST_VOTO_EM_TRANSITO                                    N
# QT_VOTOS_NOMINAIS                                    863
#
#                                                                        180   \
# DT_GERACAO                                                       24/09/2019
# HH_GERACAO                                                         19:36:33
# ANO_ELEICAO                                                            2018
# CD_TIPO_ELEICAO                                                           2
# NM_TIPO_ELEICAO                                           Eleição Ordinária
# NR_TURNO                                                                  2
# CD_ELEICAO                                                              298
# DS_ELEICAO                                   ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                                       28/10/2018
# TP_ABRANGENCIA                                                            E
# SG_UF                                                                    SC
# SG_UE                                                                    SC
# NM_UE                                                        SANTA CATARINA
# CD_MUNICIPIO                                                          80675
# NM_MUNICIPIO                                                      CAMPO ERÊ
# NR_ZONA                                                                  69
# CD_CARGO                                                                  3
# DS_CARGO                                                         Governador
# SQ_CANDIDATO                                                   240000621321
# NR_CANDIDATO                                                             55
# NM_CANDIDATO                                            GELSON LUIZ MERÍSIO
# NM_URNA_CANDIDATO                                            GELSON MERÍSIO
# NM_SOCIAL_CANDIDATO                                                  #NULO#
# CD_SITUACAO_CANDIDATURA                                                  12
# DS_SITUACAO_CANDIDATURA                                                APTO
# CD_DETALHE_SITUACAO_CAND                                                  2
# DS_DETALHE_SITUACAO_CAND                                           DEFERIDO
# TP_AGREMIACAO                                                     Coligação
# NR_PARTIDO                                                               55
# SG_PARTIDO                                                              PSD
# NM_PARTIDO                                       Partido Social Democrático
# SQ_COLIGACAO                                                   240000050553
# NM_COLIGACAO                                                AQUI É TRABALHO
# DS_COMPOSICAO_COLIGACAO   PSD / PRB / PDT / PSB / PODE / SOLIDARIEDADE /...
# CD_SIT_TOT_TURNO                                                          4
# DS_SIT_TOT_TURNO                                                 NÃO ELEITO
# ST_VOTO_EM_TRANSITO                                                       N
# QT_VOTOS_NOMINAIS                                                      2075
#
#                                                     182   \
# DT_GERACAO                                    24/09/2019
# HH_GERACAO                                      19:36:33
# ANO_ELEICAO                                         2018
# CD_TIPO_ELEICAO                                        2
# NM_TIPO_ELEICAO                        Eleição Ordinária
# NR_TURNO                                               2
# CD_ELEICAO                                           298
# DS_ELEICAO                ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                    28/10/2018
# TP_ABRANGENCIA                                         E
# SG_UF                                                 SC
# SG_UE                                                 SC
# NM_UE                                     SANTA CATARINA
# CD_MUNICIPIO                                       81183
# NM_MUNICIPIO                      SÃO PEDRO DE ALCÂNTARA
# NR_ZONA                                               29
# CD_CARGO                                               3
# DS_CARGO                                      Governador
# SQ_CANDIDATO                                240000609724
# NR_CANDIDATO                                          17
# NM_CANDIDATO                      CARLOS MOISÉS DA SILVA
# NM_URNA_CANDIDATO                      COMANDANTE MOISÉS
# NM_SOCIAL_CANDIDATO                               #NULO#
# CD_SITUACAO_CANDIDATURA                               12
# DS_SITUACAO_CANDIDATURA                             APTO
# CD_DETALHE_SITUACAO_CAND                               2
# DS_DETALHE_SITUACAO_CAND                        DEFERIDO
# TP_AGREMIACAO                            Partido isolado
# NR_PARTIDO                                            17
# SG_PARTIDO                                           PSL
# NM_PARTIDO                        Partido Social Liberal
# SQ_COLIGACAO                                240000050254
# NM_COLIGACAO                             PARTIDO ISOLADO
# DS_COMPOSICAO_COLIGACAO                              PSL
# CD_SIT_TOT_TURNO                                       1
# DS_SIT_TOT_TURNO                                  ELEITO
# ST_VOTO_EM_TRANSITO                                    N
# QT_VOTOS_NOMINAIS                                   2320
#
#                                                                        220   \
# DT_GERACAO                                                       24/09/2019
# HH_GERACAO                                                         19:36:33
# ANO_ELEICAO                                                            2018
# CD_TIPO_ELEICAO                                                           2
# NM_TIPO_ELEICAO                                           Eleição Ordinária
# NR_TURNO                                                                  2
# CD_ELEICAO                                                              298
# DS_ELEICAO                                   ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                                       28/10/2018
# TP_ABRANGENCIA                                                            E
# SG_UF                                                                    SC
# SG_UE                                                                    SC
# NM_UE                                                        SANTA CATARINA
# CD_MUNICIPIO                                                          81000
# NM_MUNICIPIO                                                         SANGÃO
# NR_ZONA                                                                  33
# CD_CARGO                                                                  3
# DS_CARGO                                                         Governador
# SQ_CANDIDATO                                                   240000621321
# NR_CANDIDATO                                                             55
# NM_CANDIDATO                                            GELSON LUIZ MERÍSIO
# NM_URNA_CANDIDATO                                            GELSON MERÍSIO
# NM_SOCIAL_CANDIDATO                                                  #NULO#
# CD_SITUACAO_CANDIDATURA                                                  12
# DS_SITUACAO_CANDIDATURA                                                APTO
# CD_DETALHE_SITUACAO_CAND                                                  2
# DS_DETALHE_SITUACAO_CAND                                           DEFERIDO
# TP_AGREMIACAO                                                     Coligação
# NR_PARTIDO                                                               55
# SG_PARTIDO                                                              PSD
# NM_PARTIDO                                       Partido Social Democrático
# SQ_COLIGACAO                                                   240000050553
# NM_COLIGACAO                                                AQUI É TRABALHO
# DS_COMPOSICAO_COLIGACAO   PSD / PRB / PDT / PSB / PODE / SOLIDARIEDADE /...
# CD_SIT_TOT_TURNO                                                          4
# DS_SIT_TOT_TURNO                                                 NÃO ELEITO
# ST_VOTO_EM_TRANSITO                                                       N
# QT_VOTOS_NOMINAIS                                                      1311
#
#                                                     1541
# DT_GERACAO                                    24/09/2019
# HH_GERACAO                                      19:36:33
# ANO_ELEICAO                                         2018
# CD_TIPO_ELEICAO                                        2
# NM_TIPO_ELEICAO                        Eleição Ordinária
# NR_TURNO                                               2
# CD_ELEICAO                                           298
# DS_ELEICAO                ELEIÇÕES GERAIS ESTADUAIS 2018
# DT_ELEICAO                                    28/10/2018
# TP_ABRANGENCIA                                         E
# SG_UF                                                 SC
# SG_UE                                                 SC
# NM_UE                                     SANTA CATARINA
# CD_MUNICIPIO                                       80390
# NM_MUNICIPIO                          BALNEÁRIO CAMBORIÚ
# NR_ZONA                                              103
# CD_CARGO                                               3
# DS_CARGO                                      Governador
# SQ_CANDIDATO                                240000609724
# NR_CANDIDATO                                          17
# NM_CANDIDATO                      CARLOS MOISÉS DA SILVA
# NM_URNA_CANDIDATO                      COMANDANTE MOISÉS
# NM_SOCIAL_CANDIDATO                               #NULO#
# CD_SITUACAO_CANDIDATURA                               12
# DS_SITUACAO_CANDIDATURA                             APTO
# CD_DETALHE_SITUACAO_CAND                               2
# DS_DETALHE_SITUACAO_CAND                        DEFERIDO
# TP_AGREMIACAO                            Partido isolado
# NR_PARTIDO                                            17
# SG_PARTIDO                                           PSL
# NM_PARTIDO                        Partido Social Liberal
# SQ_COLIGACAO                                240000050254
# NM_COLIGACAO                             PARTIDO ISOLADO
# DS_COMPOSICAO_COLIGACAO                              PSL
# CD_SIT_TOT_TURNO                                       1
# DS_SIT_TOT_TURNO                                  ELEITO
# ST_VOTO_EM_TRANSITO                                    N
# QT_VOTOS_NOMINAIS                                   9383

# %%
df_votosc['CD_MUNICIPIO'].nunique()
# Out:
# 295

# %%
df_votosc[df_votosc['NM_MUNICIPIO']=='JOINVILLE']
# Out:
#         DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 79986   24/09/2019   19:36:33         2018                2
# 81146   24/09/2019   19:36:33         2018                2
# 94207   24/09/2019   19:36:33         2018                2
# 102410  24/09/2019   19:36:33         2018                2
# 108467  24/09/2019   19:36:33         2018                2
# 119328  24/09/2019   19:36:33         2018                2
# 142170  24/09/2019   19:36:33         2018                2
# 151898  24/09/2019   19:36:33         2018                2
# 188271  24/09/2019   19:36:33         2018                2
# 203286  24/09/2019   19:36:33         2018                2
#
#           NM_TIPO_ELEICAO  NR_TURNO  CD_ELEICAO  \
# 79986   Eleição Ordinária         2         298
# 81146   Eleição Ordinária         2         298
# 94207   Eleição Ordinária         2         298
# 102410  Eleição Ordinária         2         298
# 108467  Eleição Ordinária         2         298
# 119328  Eleição Ordinária         2         298
# 142170  Eleição Ordinária         2         298
# 151898  Eleição Ordinária         2         298
# 188271  Eleição Ordinária         2         298
# 203286  Eleição Ordinária         2         298
#
#                             DS_ELEICAO  DT_ELEICAO TP_ABRANGENCIA  ...  \
# 79986   ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
# 81146   ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
# 94207   ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
# 102410  ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
# 108467  ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
# 119328  ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
# 142170  ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
# 151898  ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
# 188271  ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
# 203286  ELEIÇÕES GERAIS ESTADUAIS 2018  28/10/2018              E  ...
#
#        NR_PARTIDO SG_PARTIDO                  NM_PARTIDO  SQ_COLIGACAO  \
# 79986          55        PSD  Partido Social Democrático  240000050553
# 81146          55        PSD  Partido Social Democrático  240000050553
# 94207          17        PSL      Partido Social Liberal  240000050254
# 102410         17        PSL      Partido Social Liberal  240000050254
# 108467         17        PSL      Partido Social Liberal  240000050254
# 119328         55        PSD  Partido Social Democrático  240000050553
# 142170         55        PSD  Partido Social Democrático  240000050553
# 151898         17        PSL      Partido Social Liberal  240000050254
# 188271         55        PSD  Partido Social Democrático  240000050553
# 203286         17        PSL      Partido Social Liberal  240000050254
#
#            NM_COLIGACAO                            DS_COMPOSICAO_COLIGACAO  \
# 79986   AQUI É TRABALHO  PSD / PRB / PDT / PSB / PODE / SOLIDARIEDADE /...
# 81146   AQUI É TRABALHO  PSD / PRB / PDT / PSB / PODE / SOLIDARIEDADE /...
# 94207   PARTIDO ISOLADO                                                PSL
# 102410  PARTIDO ISOLADO                                                PSL
# 108467  PARTIDO ISOLADO                                                PSL
# 119328  AQUI É TRABALHO  PSD / PRB / PDT / PSB / PODE / SOLIDARIEDADE /...
# 142170  AQUI É TRABALHO  PSD / PRB / PDT / PSB / PODE / SOLIDARIEDADE /...
# 151898  PARTIDO ISOLADO                                                PSL
# 188271  AQUI É TRABALHO  PSD / PRB / PDT / PSB / PODE / SOLIDARIEDADE /...
# 203286  PARTIDO ISOLADO                                                PSL
#
#         CD_SIT_TOT_TURNO DS_SIT_TOT_TURNO  ST_VOTO_EM_TRANSITO  \
# 79986                  4       NÃO ELEITO                    N
# 81146                  4       NÃO ELEITO                    N
# 94207                  1           ELEITO                    N
# 102410                 1           ELEITO                    N
# 108467                 1           ELEITO                    N
# 119328                 4       NÃO ELEITO                    N
# 142170                 4       NÃO ELEITO                    N
# 151898                 1           ELEITO                    N
# 188271                 4       NÃO ELEITO                    N
# 203286                 1           ELEITO                    N
#
#         QT_VOTOS_NOMINAIS
# 79986               13731
# 81146               13964
# 94207               49034
# 102410              52939
# 108467              41111
# 119328              13813
# 142170              18301
# 151898              48225
# 188271              13456
# 203286              40211
#
# [10 rows x 38 columns]

# %%
df_votosc = df_votosc[['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO','NM_URNA_CANDIDATO', 'QT_VOTOS_NOMINAIS']]

df_votosc.head()
# Out:
#      SG_UF  CD_MUNICIPIO            NM_MUNICIPIO  NR_CANDIDATO  \
# 131     SC         82066                  MAREMA            17
# 180     SC         80675               CAMPO ERÊ            55
# 182     SC         81183  SÃO PEDRO DE ALCÂNTARA            17
# 220     SC         81000                  SANGÃO            55
# 1541    SC         80390      BALNEÁRIO CAMBORIÚ            17
#
#       NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS
# 131   COMANDANTE MOISÉS                863
# 180      GELSON MERÍSIO               2075
# 182   COMANDANTE MOISÉS               2320
# 220      GELSON MERÍSIO               1311
# 1541  COMANDANTE MOISÉS               9383

# %%
df_votosc = df_votosc.groupby(['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO',
                               'NR_CANDIDATO', 'NM_URNA_CANDIDATO',]).sum().reset_index()

df_votosc.head(5)
# Out:
#   SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO  NM_URNA_CANDIDATO  \
# 0    SC         80004     MONTE CARLO            17  COMANDANTE MOISÉS
# 1    SC         80004     MONTE CARLO            55     GELSON MERÍSIO
# 2    SC         80012    ABELARDO LUZ            17  COMANDANTE MOISÉS
# 3    SC         80012    ABELARDO LUZ            55     GELSON MERÍSIO
# 4    SC         80020  IPORÃ DO OESTE            17  COMANDANTE MOISÉS
#
#    QT_VOTOS_NOMINAIS
# 0               2408
# 1               2369
# 2               4537
# 3               3473
# 4               2999

# %%
df_votosc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590 entries, 0 to 589
# Data columns (total 6 columns):
# SG_UF                590 non-null object
# CD_MUNICIPIO         590 non-null int64
# NM_MUNICIPIO         590 non-null object
# NR_CANDIDATO         590 non-null int64
# NM_URNA_CANDIDATO    590 non-null object
# QT_VOTOS_NOMINAIS    590 non-null int64
# dtypes: int64(3), object(3)
# memory usage: 27.7+ KB

# %%
df_votosc.sort_values(by='QT_VOTOS_NOMINAIS', ascending=False).head(10)
# Out:
#     SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO  NM_URNA_CANDIDATO  \
# 358    SC         81795       JOINVILLE            17  COMANDANTE MOISÉS
# 210    SC         81051   FLORIANÓPOLIS            17  COMANDANTE MOISÉS
# 94     SC         80470        BLUMENAU            17  COMANDANTE MOISÉS
# 512    SC         83275        SÃO JOSÉ            17  COMANDANTE MOISÉS
# 211    SC         81051   FLORIANÓPOLIS            55     GELSON MERÍSIO
# 178    SC         80896        CRICIÚMA            17  COMANDANTE MOISÉS
# 322    SC         81612          ITAJAÍ            17  COMANDANTE MOISÉS
# 359    SC         81795       JOINVILLE            55     GELSON MERÍSIO
# 350    SC         81752  JARAGUÁ DO SUL            17  COMANDANTE MOISÉS
# 418    SC         82333         PALHOÇA            17  COMANDANTE MOISÉS
#
#      QT_VOTOS_NOMINAIS
# 358             231520
# 210             162127
# 94              144006
# 512              88544
# 211              80207
# 178              79768
# 322              77975
# 359              73265
# 350              68439
# 418              63003

# %%
df_votosc.sort_values(by='QT_VOTOS_NOMINAIS', ascending=False, inplace=True)

# %%
df_votosc.drop_duplicates(subset='CD_MUNICIPIO', keep='first', inplace=True)

# %%
df_votosc.head(10)
# Out:
#     SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO  NM_URNA_CANDIDATO  \
# 358    SC         81795       JOINVILLE            17  COMANDANTE MOISÉS
# 210    SC         81051   FLORIANÓPOLIS            17  COMANDANTE MOISÉS
# 94     SC         80470        BLUMENAU            17  COMANDANTE MOISÉS
# 512    SC         83275        SÃO JOSÉ            17  COMANDANTE MOISÉS
# 178    SC         80896        CRICIÚMA            17  COMANDANTE MOISÉS
# 322    SC         81612          ITAJAÍ            17  COMANDANTE MOISÉS
# 350    SC         81752  JARAGUÁ DO SUL            17  COMANDANTE MOISÉS
# 418    SC         82333         PALHOÇA            17  COMANDANTE MOISÉS
# 162    SC         80810         CHAPECÓ            17  COMANDANTE MOISÉS
# 366    SC         81833           LAGES            17  COMANDANTE MOISÉS
#
#      QT_VOTOS_NOMINAIS
# 358             231520
# 210             162127
# 94              144006
# 512              88544
# 178              79768
# 322              77975
# 350              68439
# 418              63003
# 162              59921
# 366              58411

# %%
df_votosc['RESULTADO']= df_votosc['NR_CANDIDATO'].apply(lambda x: x == 17 )

df_votosc.head(10)
# Out:
#     SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO  NM_URNA_CANDIDATO  \
# 358    SC         81795       JOINVILLE            17  COMANDANTE MOISÉS
# 210    SC         81051   FLORIANÓPOLIS            17  COMANDANTE MOISÉS
# 94     SC         80470        BLUMENAU            17  COMANDANTE MOISÉS
# 512    SC         83275        SÃO JOSÉ            17  COMANDANTE MOISÉS
# 178    SC         80896        CRICIÚMA            17  COMANDANTE MOISÉS
# 322    SC         81612          ITAJAÍ            17  COMANDANTE MOISÉS
# 350    SC         81752  JARAGUÁ DO SUL            17  COMANDANTE MOISÉS
# 418    SC         82333         PALHOÇA            17  COMANDANTE MOISÉS
# 162    SC         80810         CHAPECÓ            17  COMANDANTE MOISÉS
# 366    SC         81833           LAGES            17  COMANDANTE MOISÉS
#
#      QT_VOTOS_NOMINAIS  RESULTADO
# 358             231520       True
# 210             162127       True
# 94              144006       True
# 512              88544       True
# 178              79768       True
# 322              77975       True
# 350              68439       True
# 418              63003       True
# 162              59921       True
# 366              58411       True

# %%
link = 'https://raw.githubusercontent.com/estadao/como-votou-sua-vizinhanca/master/data/votos/correspondencia-tse-ibge.csv'

df_link = pd.read_csv(link)

df_link.head()
# Out:
#              chave          NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# 0    ac acrelandia    ACRELÂNDIA  AC      1200013     1120    NaN
# 1  ac assis brasil  ASSIS BRASIL  AC      1200054     1570    NaN
# 2     ac brasileia     BRASILÉIA  AC      1200104     1058    NaN
# 3        ac bujari        BUJARI  AC      1200138     1007    NaN
# 4      ac capixaba      CAPIXABA  AC      1200179     1015    NaN

# %%
df_votosc1 = df_votosc.copy()

df_votosc1.set_index('CD_MUNICIPIO', drop=False, inplace=True)

df_votosc1.head()
# Out:
#              SG_UF  CD_MUNICIPIO   NM_MUNICIPIO  NR_CANDIDATO  \
# CD_MUNICIPIO
# 81795           SC         81795      JOINVILLE            17
# 81051           SC         81051  FLORIANÓPOLIS            17
# 80470           SC         80470       BLUMENAU            17
# 83275           SC         83275       SÃO JOSÉ            17
# 80896           SC         80896       CRICIÚMA            17
#
#               NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS  RESULTADO
# CD_MUNICIPIO
# 81795         COMANDANTE MOISÉS             231520       True
# 81051         COMANDANTE MOISÉS             162127       True
# 80470         COMANDANTE MOISÉS             144006       True
# 83275         COMANDANTE MOISÉS              88544       True
# 80896         COMANDANTE MOISÉS              79768       True

# %%
df_link1 = df_link.copy()

df_link1.set_index('COD_TSE', drop=False, inplace=True)

df_link1.head()
# Out:
#                    chave          NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# COD_TSE
# 1120       ac acrelandia    ACRELÂNDIA  AC      1200013     1120    NaN
# 1570     ac assis brasil  ASSIS BRASIL  AC      1200054     1570    NaN
# 1058        ac brasileia     BRASILÉIA  AC      1200104     1058    NaN
# 1007           ac bujari        BUJARI  AC      1200138     1007    NaN
# 1015         ac capixaba      CAPIXABA  AC      1200179     1015    NaN

# %%
df_link1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 1120 to 96431
# Data columns (total 6 columns):
# chave          5570 non-null object
# NOME           5570 non-null object
# UF             5570 non-null object
# GEOCOD_IBGE    5570 non-null int64
# COD_TSE        5570 non-null int64
# AJUSTE         29 non-null object
# dtypes: int64(2), object(4)
# memory usage: 304.6+ KB

# %%
df_votosc1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 295 entries, 81795 to 81205
# Data columns (total 7 columns):
# SG_UF                295 non-null object
# CD_MUNICIPIO         295 non-null int64
# NM_MUNICIPIO         295 non-null object
# NR_CANDIDATO         295 non-null int64
# NM_URNA_CANDIDATO    295 non-null object
# QT_VOTOS_NOMINAIS    295 non-null int64
# RESULTADO            295 non-null bool
# dtypes: bool(1), int64(3), object(3)
# memory usage: 16.4+ KB

# %%
df_votosc2 = df_votosc1.join(df_link1)

df_votosc2.head()
# Out:
#              SG_UF  CD_MUNICIPIO   NM_MUNICIPIO  NR_CANDIDATO  \
# CD_MUNICIPIO
# 81795           SC         81795      JOINVILLE            17
# 81051           SC         81051  FLORIANÓPOLIS            17
# 80470           SC         80470       BLUMENAU            17
# 83275           SC         83275       SÃO JOSÉ            17
# 80896           SC         80896       CRICIÚMA            17
#
#               NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS  RESULTADO  \
# CD_MUNICIPIO
# 81795         COMANDANTE MOISÉS             231520       True
# 81051         COMANDANTE MOISÉS             162127       True
# 80470         COMANDANTE MOISÉS             144006       True
# 83275         COMANDANTE MOISÉS              88544       True
# 80896         COMANDANTE MOISÉS              79768       True
#
#                          chave           NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# CD_MUNICIPIO
# 81795             sc joinville      JOINVILLE  SC      4209102    81795    NaN
# 81051         sc florianopolis  FLORIANÓPOLIS  SC      4205407    81051    NaN
# 80470              sc blumenau       BLUMENAU  SC      4202404    80470    NaN
# 83275              sc sao jose       SÃO JOSÉ  SC      4216602    83275    NaN
# 80896              sc criciuma       CRICIÚMA  SC      4204608    80896    NaN

# %%
df_votosc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 295 entries, 81795 to 81205
# Data columns (total 13 columns):
# SG_UF                295 non-null object
# CD_MUNICIPIO         295 non-null int64
# NM_MUNICIPIO         295 non-null object
# NR_CANDIDATO         295 non-null int64
# NM_URNA_CANDIDATO    295 non-null object
# QT_VOTOS_NOMINAIS    295 non-null int64
# RESULTADO            295 non-null bool
# chave                295 non-null object
# NOME                 295 non-null object
# UF                   295 non-null object
# GEOCOD_IBGE          295 non-null int64
# COD_TSE              295 non-null int64
# AJUSTE               3 non-null object
# dtypes: bool(1), int64(5), object(7)
# memory usage: 40.2+ KB

# %%
df_mapsc.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 3 columns):
# NM_MUNICIP    5572 non-null object
# CD_GEOCMU     5572 non-null object
# geometry      5572 non-null object
# dtypes: object(3)
# memory usage: 130.7+ KB

# %%
df_mapsc.head()
# Out:
#                    NM_MUNICIP CD_GEOCMU  \
# 0                      CAIUÃ   3509106
# 1                    CASTILHO   3511003
# 2                     DRACENA   3514403
# 3            ESTRELA DO NORTE   3515301
# 4  EUCLIDES DA CUNHA PAULISTA   3515350
#
#                                             geometry
# 0  POLYGON ((-51.86001052999998 -21.5807199056459...
# 1  POLYGON ((-51.41936432700003 -20.6810765586240...
# 2  POLYGON ((-51.48515406800003 -21.4276462056422...
# 3  POLYGON ((-51.57097467399996 -22.3988718766653...
# 4  POLYGON ((-52.44569233499996 -22.6082794076701...

# %%
df_votosc2['GEOCOD_IBGE'] = df_votosc2['GEOCOD_IBGE'].astype(str)

df_votosc2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 295 entries, 81795 to 81205
# Data columns (total 13 columns):
# SG_UF                295 non-null object
# CD_MUNICIPIO         295 non-null int64
# NM_MUNICIPIO         295 non-null object
# NR_CANDIDATO         295 non-null int64
# NM_URNA_CANDIDATO    295 non-null object
# QT_VOTOS_NOMINAIS    295 non-null int64
# RESULTADO            295 non-null bool
# chave                295 non-null object
# NOME                 295 non-null object
# UF                   295 non-null object
# GEOCOD_IBGE          295 non-null object
# COD_TSE              295 non-null int64
# AJUSTE               3 non-null object
# dtypes: bool(1), int64(4), object(8)
# memory usage: 40.2+ KB

# %%
df_mapsc.set_index('CD_GEOCMU', drop=False, inplace=True)

# %%
df_mapsc.head()
# Out:
#                            NM_MUNICIP CD_GEOCMU  \
# CD_GEOCMU
# 3509106                        CAIUÃ   3509106
# 3511003                      CASTILHO   3511003
# 3514403                       DRACENA   3514403
# 3515301              ESTRELA DO NORTE   3515301
# 3515350    EUCLIDES DA CUNHA PAULISTA   3515350
#
#                                                     geometry
# CD_GEOCMU
# 3509106    POLYGON ((-51.86001052999998 -21.5807199056459...
# 3511003    POLYGON ((-51.41936432700003 -20.6810765586240...
# 3514403    POLYGON ((-51.48515406800003 -21.4276462056422...
# 3515301    POLYGON ((-51.57097467399996 -22.3988718766653...
# 3515350    POLYGON ((-52.44569233499996 -22.6082794076701...

# %%
df_votosc2.set_index('GEOCOD_IBGE', drop=False, inplace=True)

# %%
df_votosc2.head()
# Out:
#             SG_UF  CD_MUNICIPIO   NM_MUNICIPIO  NR_CANDIDATO  \
# GEOCOD_IBGE
# 4209102        SC         81795      JOINVILLE            17
# 4205407        SC         81051  FLORIANÓPOLIS            17
# 4202404        SC         80470       BLUMENAU            17
# 4216602        SC         83275       SÃO JOSÉ            17
# 4204608        SC         80896       CRICIÚMA            17
#
#              NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS  RESULTADO  \
# GEOCOD_IBGE
# 4209102      COMANDANTE MOISÉS             231520       True
# 4205407      COMANDANTE MOISÉS             162127       True
# 4202404      COMANDANTE MOISÉS             144006       True
# 4216602      COMANDANTE MOISÉS              88544       True
# 4204608      COMANDANTE MOISÉS              79768       True
#
#                         chave           NOME  UF GEOCOD_IBGE  COD_TSE AJUSTE
# GEOCOD_IBGE
# 4209102          sc joinville      JOINVILLE  SC     4209102    81795    NaN
# 4205407      sc florianopolis  FLORIANÓPOLIS  SC     4205407    81051    NaN
# 4202404           sc blumenau       BLUMENAU  SC     4202404    80470    NaN
# 4216602           sc sao jose       SÃO JOSÉ  SC     4216602    83275    NaN
# 4204608           sc criciuma       CRICIÚMA  SC     4204608    80896    NaN

# %%
df_mapsc1 = df_mapsc.join(df_votosc2)

df_mapsc1.head().T
# Out:
# CD_GEOCMU                                                    3509106  \
# NM_MUNICIP                                                    CAIUÃ
# CD_GEOCMU                                                    3509106
# geometry           POLYGON ((-51.86001052999998 -21.5807199056459...
# SG_UF                                                            NaN
# CD_MUNICIPIO                                                     NaN
# NM_MUNICIPIO                                                     NaN
# NR_CANDIDATO                                                     NaN
# NM_URNA_CANDIDATO                                                NaN
# QT_VOTOS_NOMINAIS                                                NaN
# RESULTADO                                                        NaN
# chave                                                            NaN
# NOME                                                             NaN
# UF                                                               NaN
# GEOCOD_IBGE                                                      NaN
# COD_TSE                                                          NaN
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    3511003  \
# NM_MUNICIP                                                  CASTILHO
# CD_GEOCMU                                                    3511003
# geometry           POLYGON ((-51.41936432700003 -20.6810765586240...
# SG_UF                                                            NaN
# CD_MUNICIPIO                                                     NaN
# NM_MUNICIPIO                                                     NaN
# NR_CANDIDATO                                                     NaN
# NM_URNA_CANDIDATO                                                NaN
# QT_VOTOS_NOMINAIS                                                NaN
# RESULTADO                                                        NaN
# chave                                                            NaN
# NOME                                                             NaN
# UF                                                               NaN
# GEOCOD_IBGE                                                      NaN
# COD_TSE                                                          NaN
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    3514403  \
# NM_MUNICIP                                                   DRACENA
# CD_GEOCMU                                                    3514403
# geometry           POLYGON ((-51.48515406800003 -21.4276462056422...
# SG_UF                                                            NaN
# CD_MUNICIPIO                                                     NaN
# NM_MUNICIPIO                                                     NaN
# NR_CANDIDATO                                                     NaN
# NM_URNA_CANDIDATO                                                NaN
# QT_VOTOS_NOMINAIS                                                NaN
# RESULTADO                                                        NaN
# chave                                                            NaN
# NOME                                                             NaN
# UF                                                               NaN
# GEOCOD_IBGE                                                      NaN
# COD_TSE                                                          NaN
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    3515301  \
# NM_MUNICIP                                          ESTRELA DO NORTE
# CD_GEOCMU                                                    3515301
# geometry           POLYGON ((-51.57097467399996 -22.3988718766653...
# SG_UF                                                            NaN
# CD_MUNICIPIO                                                     NaN
# NM_MUNICIPIO                                                     NaN
# NR_CANDIDATO                                                     NaN
# NM_URNA_CANDIDATO                                                NaN
# QT_VOTOS_NOMINAIS                                                NaN
# RESULTADO                                                        NaN
# chave                                                            NaN
# NOME                                                             NaN
# UF                                                               NaN
# GEOCOD_IBGE                                                      NaN
# COD_TSE                                                          NaN
# AJUSTE                                                           NaN
#
# CD_GEOCMU                                                    3515350
# NM_MUNICIP                                EUCLIDES DA CUNHA PAULISTA
# CD_GEOCMU                                                    3515350
# geometry           POLYGON ((-52.44569233499996 -22.6082794076701...
# SG_UF                                                            NaN
# CD_MUNICIPIO                                                     NaN
# NM_MUNICIPIO                                                     NaN
# NR_CANDIDATO                                                     NaN
# NM_URNA_CANDIDATO                                                NaN
# QT_VOTOS_NOMINAIS                                                NaN
# RESULTADO                                                        NaN
# chave                                                            NaN
# NOME                                                             NaN
# UF                                                               NaN
# GEOCOD_IBGE                                                      NaN
# COD_TSE                                                          NaN
# AJUSTE                                                           NaN

# %%
df_mapsc1.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 5572 entries, 3509106 to 1101807
# Data columns (total 16 columns):
# NM_MUNICIP           5572 non-null object
# CD_GEOCMU            5572 non-null object
# geometry             5572 non-null object
# SG_UF                295 non-null object
# CD_MUNICIPIO         295 non-null float64
# NM_MUNICIPIO         295 non-null object
# NR_CANDIDATO         295 non-null float64
# NM_URNA_CANDIDATO    295 non-null object
# QT_VOTOS_NOMINAIS    295 non-null float64
# RESULTADO            295 non-null object
# chave                295 non-null object
# NOME                 295 non-null object
# UF                   295 non-null object
# GEOCOD_IBGE          295 non-null object
# COD_TSE              295 non-null float64
# AJUSTE               3 non-null object
# dtypes: float64(4), object(12)
# memory usage: 900.0+ KB

# %%
df_mapsc1[df_mapsc1['NR_CANDIDATO'].isnull()]
# Out:
#                            NM_MUNICIP CD_GEOCMU  \
# CD_GEOCMU
# 3509106                        CAIUÃ   3509106
# 3511003                      CASTILHO   3511003
# 3514403                       DRACENA   3514403
# 3515301              ESTRELA DO NORTE   3515301
# 3515350    EUCLIDES DA CUNHA PAULISTA   3515350
# 3528700              MARABÃ PAULISTA   3528700
# 3530201       MIRANTE DO PARANAPANEMA   3530201
# 3531605                 MONTE CASTELO   3531605
# 3532207                     NARANDIBA   3532207
# 3533106             NOVA GUATAPORANGA   3533106
# 3534807                    OURO VERDE   3534807
# 3535408                      PANORAMA   3535408
# 3536406                    PAULICÃIA   3536406
# 3538303                     PIQUEROBI   3538303
# 3541208          PRESIDENTE BERNARDES   3541208
# 3541307          PRESIDENTE EPITÃCIO   3541307
# 3541505          PRESIDENTE VENCESLAU   3541505
# 3543238         RIBEIRÃO DOS ÃNDIOS   3543238
# 3544251                        ROSANA   3544251
# 3545506                   SANDOVALINA   3545506
# 3547106                SANTA MERCEDES   3547106
# 3547700              SANTO ANASTÃCIO   3547700
# 3549300      SÃO JOÃO DO PAU D'ALHO   3549300
# 3553906                       TARABAI   3553906
# 3554300               TEODORO SAMPAIO   3554300
# 3555109                 TUPI PAULISTA   3555109
# 4300001                   LAGOA MIRIM   4300001
# 4300034                       ACEGUÃ   4300034
# 4300059                   ÃGUA SANTA   4300059
# 4300109                         AGUDO   4300109
# ...                               ...       ...
# 1100320       SÃO MIGUEL DO GUAPORÃ   1100320
# 1100338                  NOVA MAMORÃ   1100338
# 1100346              ALVORADA D'OESTE   1100346
# 1100379       ALTO ALEGRE DOS PARECIS   1100379
# 1100403                 ALTO PARAÃSO   1100403
# 1100452                       BURITIS   1100452
# 1100502       NOVO HORIZONTE DO OESTE   1100502
# 1100601                  CACAULÃNDIA   1100601
# 1100700       CAMPO NOVO DE RONDÃNIA   1100700
# 1100809            CANDEIAS DO JAMARI   1100809
# 1100908                  CASTANHEIRAS   1100908
# 1100924                   CHUPINGUAIA   1100924
# 1100940                       CUJUBIM   1100940
# ...                                                      ...   ...
# 1100320    POLYGON ((-63.19546149699995 -11.1033892883570...   NaN
# 1100338    POLYGON ((-64.34116988100003 -10.0003818453231...   NaN
# 1100346    POLYGON ((-62.15922520499998 -11.0677529953558...   NaN
# 1100379    POLYGON ((-61.88843533599992 -11.9657111283831...   NaN
# 1100403    POLYGON ((-63.32597594000002 -9.42850504830529...   NaN
# 1100452    POLYGON ((-63.68529268399993 -9.83298563931786...   NaN
# 1100502    POLYGON ((-61.91377805499998 -11.5850238443715...   NaN
# 1100601    POLYGON ((-62.67077469099999 -10.2877756193320...   NaN
# 1100700    POLYGON ((-63.52430474999993 -10.2496429133307...   NaN
# 1100809    POLYGON ((-62.76413575599988 -8.79806302228555...   NaN
# 1100908    POLYGON ((-61.79579824599999 -11.3978323213660...   NaN
# 1100924    POLYGON ((-60.64998529999991 -12.2613712443920...   NaN
# 1100940    POLYGON ((-62.36912690199998 -8.74355692928383...   NaN
# 1101005    POLYGON ((-62.78805426299986 -10.4924814293382...   NaN
# 1101104    POLYGON ((-62.76413575599988 -8.79806302228555...   NaN
# 1101203    POLYGON ((-61.42900212300002 -10.9875342133535...   NaN
# 1101302    POLYGON ((-62.54910889600002 -11.0660172253558...   NaN
# 1101401    POLYGON ((-63.20926544299998 -10.1670111073282...   NaN
# 1101435    POLYGON ((-62.35243528599994 -10.8939343703505...   NaN
# 1101450    POLYGON ((-61.18067348099998 -12.1671429153891...   NaN
# 1101468    POLYGON ((-61.34201008899997 -12.626096251403,...   NaN
# 1101476    POLYGON ((-61.19016785299995 -12.0005080363842...   NaN
# 1101484    POLYGON ((-61.4148365289999 -11.74399325937653...   NaN
# 1101492    POLYGON ((-63.58109461000001 -11.8390426183793...   NaN
# 1101500    POLYGON ((-63.12888162800003 -12.2020482013903...   NaN
# 1101559    POLYGON ((-62.12258034699995 -10.8993878293507...   NaN
# 1101609    POLYGON ((-61.95441777099997 -9.94967983232152...   NaN
# 1101708    POLYGON ((-62.15601492699993 -11.0259823423546...   NaN
# 1101757    POLYGON ((-61.57463730400001 -9.71779325731429...   NaN
# 1101807    POLYGON ((-61.97266710100002 -10.0675279283251...   NaN
#
#            CD_MUNICIPIO NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# CD_GEOCMU
# 3509106             NaN          NaN           NaN               NaN
# 3511003             NaN          NaN           NaN               NaN
# 3514403             NaN          NaN           NaN               NaN
# 3515301             NaN          NaN           NaN               NaN
# 3515350             NaN          NaN           NaN               NaN
# 3528700             NaN          NaN           NaN               NaN
# 3530201             NaN          NaN           NaN               NaN
# 3531605             NaN          NaN           NaN               NaN
# 3532207             NaN          NaN           NaN               NaN
# 3533106             NaN          NaN           NaN               NaN
# 3534807             NaN          NaN           NaN               NaN
# 3535408             NaN          NaN           NaN               NaN
# 3536406             NaN          NaN           NaN               NaN
# 3538303             NaN          NaN           NaN               NaN
# 3541208             NaN          NaN           NaN               NaN
# 3541307             NaN          NaN           NaN               NaN
# 3541505             NaN          NaN           NaN               NaN
# 3543238             NaN          NaN           NaN               NaN
# 3544251             NaN          NaN           NaN               NaN
# 3545506             NaN          NaN           NaN               NaN
# 3547106             NaN          NaN           NaN               NaN
# 3547700             NaN          NaN           NaN               NaN
# 3549300             NaN          NaN           NaN               NaN
# 3553906             NaN          NaN           NaN               NaN
# 3554300             NaN          NaN           NaN               NaN
# 3555109             NaN          NaN           NaN               NaN
# 4300001             NaN          NaN           NaN               NaN
# 4300034             NaN          NaN           NaN               NaN
# 4300059             NaN          NaN           NaN               NaN
# 4300109             NaN          NaN           NaN               NaN
# ...                 ...          ...           ...               ...
# 1100320             NaN          NaN           NaN               NaN
# 1100338             NaN          NaN           NaN               NaN
# 1100346             NaN          NaN           NaN               NaN
# 1100379             NaN          NaN           NaN               NaN
# 1100403             NaN          NaN           NaN               NaN
# 1100452             NaN          NaN           NaN               NaN
# 1100502             NaN          NaN           NaN               NaN
# 1100601             NaN          NaN           NaN               NaN
# 1100700             NaN          NaN           NaN               NaN
# 1100809             NaN          NaN           NaN               NaN
# 1100908             NaN          NaN           NaN               NaN
# 1100924             NaN          NaN           NaN               NaN
# 1100940             NaN          NaN           NaN               NaN
# 1101005             NaN          NaN           NaN               NaN
# 1101104             NaN          NaN           NaN               NaN
# 1101203             NaN          NaN           NaN               NaN
# 1101302             NaN          NaN           NaN               NaN
# 1101401             NaN          NaN           NaN               NaN
# 1101435             NaN          NaN           NaN               NaN
# 1101450             NaN          NaN           NaN               NaN
# 1101468             NaN          NaN           NaN               NaN
# 1101476             NaN          NaN           NaN               NaN
# 1101484             NaN          NaN           NaN               NaN
# 1101492             NaN          NaN           NaN               NaN
# 1101500             NaN          NaN           NaN               NaN
# 1101559             NaN          NaN           NaN               NaN
# 1101609             NaN          NaN           NaN               NaN
# 1101708             NaN          NaN           NaN               NaN
# 1101757             NaN          NaN           NaN               NaN
# 1101807             NaN          NaN           NaN               NaN
#
#            QT_VOTOS_NOMINAIS RESULTADO chave NOME   UF GEOCOD_IBGE  COD_TSE  \
# CD_GEOCMU
# 3509106                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3511003                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3514403                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3515301                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3515350                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3528700                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3530201                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3531605                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3532207                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3533106                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3534807                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3535408                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3536406                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3538303                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3541208                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3541307                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3541505                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3543238                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3544251                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3545506                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3547106                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3547700                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3549300                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3553906                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3554300                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 3555109                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 4300001                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 4300034                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 4300059                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 4300109                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# ...                      ...       ...   ...  ...  ...         ...      ...
# 1100320                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1100338                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1100346                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1100379                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1100403                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1100452                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1100502                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1100601                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1100700                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1100809                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1100908                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1100924                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1100940                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101005                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101104                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101203                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101302                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101401                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101435                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101450                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101468                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101476                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101484                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101492                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101500                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101559                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101609                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101708                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101757                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 1101807                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
#
#           AJUSTE
# CD_GEOCMU
# 3509106      NaN
# 3511003      NaN
# 3514403      NaN
# 3515301      NaN
# 3515350      NaN
# 3528700      NaN
# 3530201      NaN
# 3531605      NaN
# 3532207      NaN
# 3533106      NaN
# 3534807      NaN
# 3535408      NaN
# 3536406      NaN
# 3538303      NaN
# 3541208      NaN
# 3541307      NaN
# 3541505      NaN
# 3543238      NaN
# 3544251      NaN
# 3545506      NaN
# 3547106      NaN
# 3547700      NaN
# 3549300      NaN
# 3553906      NaN
# 3554300      NaN
# 3555109      NaN
# 4300001      NaN
# 4300034      NaN
# 4300059      NaN
# 4300109      NaN
# ...          ...
# 1100320      NaN
# 1100338      NaN
# 1100346      NaN
# 1100379      NaN
# 1100403      NaN
# 1100452      NaN
# 1100502      NaN
# 1100601      NaN
# 1100700      NaN
# 1100809      NaN
# 1100908      NaN
# 1100924      NaN
# 1100940      NaN
# 1101005      NaN
# 1101104      NaN
# 1101203      NaN
# 1101302      NaN
# 1101401      NaN
# 1101435      NaN
# 1101450      NaN
# 1101468      NaN
# 1101476      NaN
# 1101484      NaN
# 1101492      NaN
# 1101500      NaN
# 1101559      NaN
# 1101609      NaN
# 1101708      NaN
# 1101757      NaN
# 1101807      NaN
#
# [5277 rows x 16 columns]

# %%
df_mapsc1.drop(columns=['AJUSTE'], inplace=True)

# %%
df_mapsc1.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 5572 entries, 3509106 to 1101807
# Data columns (total 15 columns):
# NM_MUNICIP           5572 non-null object
# CD_GEOCMU            5572 non-null object
# geometry             5572 non-null object
# SG_UF                295 non-null object
# CD_MUNICIPIO         295 non-null float64
# NM_MUNICIPIO         295 non-null object
# NR_CANDIDATO         295 non-null float64
# NM_URNA_CANDIDATO    295 non-null object
# QT_VOTOS_NOMINAIS    295 non-null float64
# RESULTADO            295 non-null object
# chave                295 non-null object
# NOME                 295 non-null object
# UF                   295 non-null object
# GEOCOD_IBGE          295 non-null object
# COD_TSE              295 non-null float64
# dtypes: float64(4), object(11)
# memory usage: 856.5+ KB

# %%
df_mapsc1.dropna(inplace=True)

# %%
df_mapsc1.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 295 entries, 4200101 to 4218509
# Data columns (total 15 columns):
# NM_MUNICIP           295 non-null object
# CD_GEOCMU            295 non-null object
# geometry             295 non-null object
# SG_UF                295 non-null object
# CD_MUNICIPIO         295 non-null float64
# NM_MUNICIPIO         295 non-null object
# NR_CANDIDATO         295 non-null float64
# NM_URNA_CANDIDATO    295 non-null object
# QT_VOTOS_NOMINAIS    295 non-null float64
# RESULTADO            295 non-null object
# chave                295 non-null object
# NOME                 295 non-null object
# UF                   295 non-null object
# GEOCOD_IBGE          295 non-null object
# COD_TSE              295 non-null float64
# dtypes: float64(4), object(11)
# memory usage: 36.9+ KB

# %%
# Vamos desenhar o mapa

# Criar a referência para o código de cor (False/0 = red, True/1 = green)
from matplotlib.colors import ListedColormap

cmap = ListedColormap(['#fc671e', '#47003d'])

# Desenhando o mapa
fig, ax = plt.subplots(1, figsize=(15, 15))

ax = df_mapsc1.plot(column='RESULTADO', cmap=cmap, legend=True, linewidth=0.1, ax=ax,
                      edgecolor='grey')

# Escondendo o eixos
ax.set_axis_off()

# Colocando um título
ax.set_title('Resultado Eleição 2018 por Município SC / 2º Turno', fontdict={'fontsize': '25', 'fontweight': '5'})

# Criando uma nota do rodapé
ax.annotate('Fonte: IBGE, 2015; TSE, 2019; Jornal o Estado de São Paulo, 2019',
    xy=(0.1, 0.2), xycoords='figure fraction', horizontalalignment='left',
    verticalalignment='top', fontsize=10, color='#555555')

# Alterando a legenda
leg = ax.get_legend()
leg.get_texts()[0].set_text('Gelson Merísio')
leg.get_texts()[1].set_text('Comandante Moises')

plt.show()
