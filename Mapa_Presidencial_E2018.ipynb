# %% [markdown]
# # Mapa do 2° Turno da Eleição Presidencial 2018 Por Munícipio

# %%
# Importamos as bibliotecas

import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
# %matplotlib inline

# %%
# Carregar o shipefile

df_mapa = gpd.read_file(r'C:\Users\Marcio\Desktop\Data Science\Mapas IBGE\BRMUE250GC_SIR.shp')

df_mapa.head()
# Out:
#                    NM_MUNICIP CD_GEOCMU  \
# 0                      CAIUÃ   3509106
# 1                    CASTILHO   3511003
# 2                     DRACENA   3514403
# 3            ESTRELA DO NORTE   3515301
# 4  EUCLIDES DA CUNHA PAULISTA   3515350
#
#                                             geometry
# 0  POLYGON ((-51.86001052999998 -21.5807199056459...
# 1  POLYGON ((-51.41936432700003 -20.6810765586240...
# 2  POLYGON ((-51.48515406800003 -21.4276462056422...
# 3  POLYGON ((-51.57097467399996 -22.3988718766653...
# 4  POLYGON ((-52.44569233499996 -22.6082794076701...

# %%
df_mapa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 3 columns):
# NM_MUNICIP    5572 non-null object
# CD_GEOCMU     5572 non-null object
# geometry      5572 non-null object
# dtypes: object(3)
# memory usage: 130.7+ KB

# %%
# Plotando o mapa em shapefile

df_mapa.plot()

# %%
# Expandir o tamanho do mapa

fig, ax = plt.subplots(1, figsize=(12,12))

df_mapa.plot(ax=ax)

# %%
# Retirar os eixos
fig, ax = plt.subplots(1, figsize=(12,12))
ax.set_axis_off()
df_mapa.plot(ax=ax)

# %%
# Carregar o arquivo com resultado da eleição

df_voto = pd.read_csv('votaPresMun.csv', sep=';', encoding='latin1')
df_voto.head().T
# Out:
#                                                    0  \
# DT_GERACAO                                24/09/2019
# HH_GERACAO                                  19:39:42
# ANO_ELEICAO                                     2018
# CD_TIPO_ELEICAO                                    2
# NM_TIPO_ELEICAO                    Eleição Ordinária
# NR_TURNO                                           2
# CD_ELEICAO                                       296
# DS_ELEICAO                ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                28/10/2018
# TP_ABRANGENCIA                                     F
# SG_UF                                             RS
# SG_UE                                             BR
# NM_UE                                         BRASIL
# CD_MUNICIPIO                                   86363
# NM_MUNICIPIO                        BARRA DO GUARITA
# NR_ZONA                                          101
# CD_CARGO                                           1
# ...

# %%
# Separar os dados apenas do 2 turno

df_voto = df_voto[df_voto['NR_TURNO']== 2]

df_voto.sample(3).T
# Out:
#                                                40010  \
# DT_GERACAO                                24/09/2019
# HH_GERACAO                                  19:39:42
# ANO_ELEICAO                                     2018
# CD_TIPO_ELEICAO                                    2
# NM_TIPO_ELEICAO                    Eleição Ordinária
# NR_TURNO                                           2
# CD_ELEICAO                                       296
# DS_ELEICAO                ELEIÇÃO GERAL FEDERAL 2018
# DT_ELEICAO                                28/10/2018
# TP_ABRANGENCIA                                     F
# SG_UF                                             SP
# SG_UE                                             BR
# NM_UE                                         BRASIL
# CD_MUNICIPIO                                   71374
# NM_MUNICIPIO                             SETE BARRAS
# NR_ZONA                                          172
# CD_CARGO                                           1
# ...

# %%
# Quantidade de município únicos no DataFrame por código de cidade

df_voto['CD_MUNICIPIO'].nunique()
# Out:
# 5741

# %%
# Mostrar zonas fora do Brasil

df_voto[df_voto['SG_UF']=='ZZ'].sample(4)
# Out:
#        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 67114  24/09/2019   19:39:42         2018                2  Eleição Ordinária
# 72710  24/09/2019   19:39:42         2018                2  Eleição Ordinária
# 26185  24/09/2019   19:39:42         2018                2  Eleição Ordinária
# 54104  24/09/2019   19:39:42         2018                2  Eleição Ordinária
#
#        NR_TURNO  CD_ELEICAO                  DS_ELEICAO  DT_ELEICAO  \
# 67114         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 72710         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 26185         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
# 54104         2         296  ELEIÇÃO GERAL FEDERAL 2018  28/10/2018
#
#       TP_ABRANGENCIA  ... NR_PARTIDO SG_PARTIDO                 NM_PARTIDO  \
# 67114              F  ...         17        PSL     Partido Social Liberal
# 72710              F  ...         13         PT  Partido dos Trabalhadores
# ...

# %%
# Quantas cidades estão fora do Brasil?

df_voto[df_voto['SG_UF']=='ZZ']['CD_MUNICIPIO'].nunique()
# Out:
# 171

# %%
# Excluindo zonas fora do Brasil do DataFrame

df_voto = df_voto[df_voto['SG_UF']!= 'ZZ']

# %%
# Conferindo o numero de cidades no DataFrame

df_voto['CD_MUNICIPIO'].nunique()
# Out:
# 5570

# %%
# Os dados estão separados por múnicipios/zona
# Municípios pequenos tem geralmente apenas uma zona eleiroral
# Municipios grades podem ter diversas Zonas eleitorais 

# Exemplo de Belo Horizonte

df_voto[df_voto['NM_MUNICIPIO']=='BELO HORIZONTE']
# Out:
#        DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 794    24/09/2019   19:39:42         2018                2  Eleição Ordinária
# 1377   24/09/2019   19:39:42         2018                2  Eleição Ordinária
# 4520   24/09/2019   19:39:42         2018                2  Eleição Ordinária
# 5503   24/09/2019   19:39:42         2018                2  Eleição Ordinária
# 6046   24/09/2019   19:39:42         2018                2  Eleição Ordinária
# 8528   24/09/2019   19:39:42         2018                2  Eleição Ordinária
# 12851  24/09/2019   19:39:42         2018                2  Eleição Ordinária
# 13280  24/09/2019   19:39:42         2018                2  Eleição Ordinária
# 17280  24/09/2019   19:39:42         2018                2  Eleição Ordinária
# 18245  24/09/2019   19:39:42         2018                2  Eleição Ordinária
# 18653  24/09/2019   19:39:42         2018                2  Eleição Ordinária
# ...

# %%
# Eliminar colunas que não serão utilizados

# Primeiro fazemos uma nova variável

df_voto = df_voto[['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO', 
                    'NM_URNA_CANDIDATO', 'QT_VOTOS_NOMINAIS']]

df_voto.head()
# Out:
#   SG_UF  CD_MUNICIPIO      NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 0    RS         86363  BARRA DO GUARITA            13   FERNANDO HADDAD
# 1    PE         25313            RECIFE            13   FERNANDO HADDAD
# 2    PB         21350       PILÕEZINHOS            13   FERNANDO HADDAD
# 3    SC         80896          CRICIÚMA            13   FERNANDO HADDAD
# 4    RJ         58831           RESENDE            13   FERNANDO HADDAD
#
#    QT_VOTOS_NOMINAIS
# 0                998
# 1              46201
# 2               3043
# 3               5072
# 4               5758

# %%
df_voto[df_voto['NM_MUNICIPIO']=='BELO HORIZONTE']
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 794      MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 1377     MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 4520     MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 5503     MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 6046     MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 8528     MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 12851    MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 13280    MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 17280    MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 18245    MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 18653    MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 24203    MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# ...

# %%
# Precisamos agregar dados por município e candidatos

df_voto.groupby(['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO', 'NM_URNA_CANDIDATO',]).sum()
# Out:
#                                                                           QT_VOTOS_NOMINAIS
# SG_UF CD_MUNICIPIO NM_MUNICIPIO           NR_CANDIDATO NM_URNA_CANDIDATO
# AC    1007         BUJARI                 13           FERNANDO HADDAD                 1274
#                                           17           JAIR BOLSONARO                  4676
#       1015         CAPIXABA               13           FERNANDO HADDAD                 1086
#                                           17           JAIR BOLSONARO                  3895
#       1023         PORTO ACRE             13           FERNANDO HADDAD                 2059
#                                           17           JAIR BOLSONARO                  7150
#       1031         SANTA ROSA DO PURUS    13           FERNANDO HADDAD                  975
#                                           17           JAIR BOLSONARO                   847
# ...

# %%
df_voto[df_voto['NM_MUNICIPIO']=='BELO HORIZONTE']
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 794      MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 1377     MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 4520     MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 5503     MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 6046     MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 8528     MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 12851    MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 13280    MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 17280    MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 18245    MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 18653    MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 24203    MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# ...

# %%
df_voto = df_voto.groupby(['SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_CANDIDATO', 'NM_URNA_CANDIDATO',]).sum().reset_index()

df_voto.sample(5)
# Out:
#       SG_UF  CD_MUNICIPIO     NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 10615    SP         69990   SALES OLIVEIRA            17    JAIR BOLSONARO
# 9960     SP         63452          CONCHAL            13   FERNANDO HADDAD
# 6491     PR         74519  BARRA DO JACARÉ            17    JAIR BOLSONARO
# 2163     GO         95672       RIANÁPOLIS            17    JAIR BOLSONARO
# 8291     RS         87017          IBIRUBÁ            17    JAIR BOLSONARO
#
#        QT_VOTOS_NOMINAIS
# 10615               4182
# 9960                2627
# 6491                1075
# 2163                1887
# 8291                8953

# %%
# Vamos analisar a cidade de Belo Horizonte para certificar que ficou apenas duas linhas de informação

df_voto[df_voto['NM_MUNICIPIO']=='BELO HORIZONTE']
# Out:
#      SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 2936    MG         41238  BELO HORIZONTE            13   FERNANDO HADDAD
# 2937    MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
#
#       QT_VOTOS_NOMINAIS
# 2936             472887
# 2937             901513

# %%
df_voto.head(20)
# Out:
#    SG_UF  CD_MUNICIPIO          NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 0     AC          1007                BUJARI            13   FERNANDO HADDAD
# 1     AC          1007                BUJARI            17    JAIR BOLSONARO
# 2     AC          1015              CAPIXABA            13   FERNANDO HADDAD
# 3     AC          1015              CAPIXABA            17    JAIR BOLSONARO
# 4     AC          1023            PORTO ACRE            13   FERNANDO HADDAD
# 5     AC          1023            PORTO ACRE            17    JAIR BOLSONARO
# 6     AC          1031   SANTA ROSA DO PURUS            13   FERNANDO HADDAD
# 7     AC          1031   SANTA ROSA DO PURUS            17    JAIR BOLSONARO
# 8     AC          1040  MARECHAL THAUMATURGO            13   FERNANDO HADDAD
# 9     AC          1040  MARECHAL THAUMATURGO            17    JAIR BOLSONARO
# 10    AC          1058             BRASILÉIA            13   FERNANDO HADDAD
# ...

# %%
# Vamor ordenar o DataFrame pela quantidade de votos e depois deixar apenas a primeira linha com mais votos de cada município

df_voto.sort_values(by='QT_VOTOS_NOMINAIS', ascending=False).head(10)
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 10723    SP         71072       SÃO PAULO            17    JAIR BOLSONARO
# 10722    SP         71072       SÃO PAULO            13   FERNANDO HADDAD
# 7369     RJ         60011  RIO DE JANEIRO            17    JAIR BOLSONARO
# 7368     RJ         60011  RIO DE JANEIRO            13   FERNANDO HADDAD
# 1607     DF         97012        BRASÍLIA            17    JAIR BOLSONARO
# 1054     BA         38490        SALVADOR            13   FERNANDO HADDAD
# 2937     MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 6659     PR         75353        CURITIBA            17    JAIR BOLSONARO
# 1376     CE         13897       FORTALEZA            13   FERNANDO HADDAD
# 309      AM          2550          MANAUS            17    JAIR BOLSONARO
#
#        QT_VOTOS_NOMINAIS
# 10723            3694834
# 10722            2424125
# 7369             2179896
# 7368             1105393
# ...

# %%
# Vamos ordenar e gravar no DataFrame

df_voto.sort_values(by='QT_VOTOS_NOMINAIS', ascending=False, inplace=True)

# Dropar as linhas duplicadas mantendo a primeira

#df_voto.drop_duplicates(subset='CD_MUNICIPIO', keep='first', inplace=True)
df_voto.drop_duplicates(subset='CD_MUNICIPIO', keep='first', inplace=True)

df_voto.head(10)
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 10723    SP         71072       SÃO PAULO            17    JAIR BOLSONARO
# 7369     RJ         60011  RIO DE JANEIRO            17    JAIR BOLSONARO
# 1607     DF         97012        BRASÍLIA            17    JAIR BOLSONARO
# 1054     BA         38490        SALVADOR            13   FERNANDO HADDAD
# 2937     MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 6659     PR         75353        CURITIBA            17    JAIR BOLSONARO
# 1376     CE         13897       FORTALEZA            13   FERNANDO HADDAD
# 309      AM          2550          MANAUS            17    JAIR BOLSONARO
# 2013     GO         93734         GOIÂNIA            17    JAIR BOLSONARO
# 5834     PE         25313          RECIFE            13   FERNANDO HADDAD
#
#        QT_VOTOS_NOMINAIS
# 10723            3694834
# 7369             2179896
# 1607             1080411
# 1054              985532
# ...

# %%
# Vamos conferir Belo Horizonte de novo

df_voto[df_voto['NM_MUNICIPIO']=='BELO HORIZONTE']
# Out:
#      SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 2937    MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
#
#       QT_VOTOS_NOMINAIS
# 2937             901513

# %%
# Agora vamos criar uma nova coluna representando o resultado (True = Bolsonaro, False=Hadad)

df_voto['RESULTADO']= df_voto['NR_CANDIDATO'].apply(lambda x: x == 17 )

df_voto.head(10)
# Out:
#       SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 10723    SP         71072       SÃO PAULO            17    JAIR BOLSONARO
# 7369     RJ         60011  RIO DE JANEIRO            17    JAIR BOLSONARO
# 1607     DF         97012        BRASÍLIA            17    JAIR BOLSONARO
# 1054     BA         38490        SALVADOR            13   FERNANDO HADDAD
# 2937     MG         41238  BELO HORIZONTE            17    JAIR BOLSONARO
# 6659     PR         75353        CURITIBA            17    JAIR BOLSONARO
# 1376     CE         13897       FORTALEZA            13   FERNANDO HADDAD
# 309      AM          2550          MANAUS            17    JAIR BOLSONARO
# 2013     GO         93734         GOIÂNIA            17    JAIR BOLSONARO
# 5834     PE         25313          RECIFE            13   FERNANDO HADDAD
#
#        QT_VOTOS_NOMINAIS  RESULTADO
# 10723            3694834       True
# 7369             2179896       True
# 1607             1080411       True
# ...

# %%
# Mostrando alguns valores do DataFrame geopandas 

df_mapa.sample(3)
# Out:
#      NM_MUNICIP CD_GEOCMU                                           geometry
# 2134      ÃLEO   3533809  POLYGON ((-49.36958604999997 -22.8834324526765...
# 3631     AIUABA   2300408  POLYGON ((-40.08510575600003 -6.36859857720825...
# 1608     ALEGRE   3200201  POLYGON ((-41.41471495400004 -20.5729054936213...

# %%
# Tentando encontrar o municipio pelo codigo

df_voto[df_voto['CD_MUNICIPIO']==320021]
# Out:
# Empty DataFrame
# Columns: [SG_UF, CD_MUNICIPIO, NM_MUNICIPIO, NR_CANDIDATO, NM_URNA_CANDIDATO, QT_VOTOS_NOMINAIS, RESULTADO]
# Index: []

# %%
# Porque não conseguimos juntar os arquivos pelo nome do municipio

df_voto[df_voto['NM_MUNICIPIO']=='OURO BRANCO']
# Out:
#      SG_UF  CD_MUNICIPIO NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# 3867    MG         49174  OURO BRANCO            17    JAIR BOLSONARO
# 174     AL         28215  OURO BRANCO            13   FERNANDO HADDAD
# 7570    RN         17698  OURO BRANCO            13   FERNANDO HADDAD
#
#       QT_VOTOS_NOMINAIS  RESULTADO
# 3867              12198       True
# 174                5156      False
# 7570               2463      False

# %%
# Recuperar a tabela de correspondencia entre o IBGE e TSE através do GitHub do Estadão

link = 'https://raw.githubusercontent.com/estadao/como-votou-sua-vizinhanca/master/data/votos/correspondencia-tse-ibge.csv'

df_equivalencia = pd.read_csv(link)

df_equivalencia.head()
# Out:
#              chave          NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# 0    ac acrelandia    ACRELÂNDIA  AC      1200013     1120    NaN
# 1  ac assis brasil  ASSIS BRASIL  AC      1200054     1570    NaN
# 2     ac brasileia     BRASILÉIA  AC      1200104     1058    NaN
# 3        ac bujari        BUJARI  AC      1200138     1007    NaN
# 4      ac capixaba      CAPIXABA  AC      1200179     1015    NaN

# %%
# Vamos preparar os DataFrames

# Vamos reindexar o dataframe de votação pelo código do TSE
df_vot_novo = df_voto.copy()

df_vot_novo.set_index('CD_MUNICIPIO', drop=False, inplace=True)

df_vot_novo.head()
# Out:
#              SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO  \
# CD_MUNICIPIO
# 71072           SP         71072       SÃO PAULO            17
# 60011           RJ         60011  RIO DE JANEIRO            17
# 97012           DF         97012        BRASÍLIA            17
# 38490           BA         38490        SALVADOR            13
# 41238           MG         41238  BELO HORIZONTE            17
#
#              NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS  RESULTADO
# CD_MUNICIPIO
# 71072           JAIR BOLSONARO            3694834       True
# 60011           JAIR BOLSONARO            2179896       True
# 97012           JAIR BOLSONARO            1080411       True
# 38490          FERNANDO HADDAD             985532      False
# 41238           JAIR BOLSONARO             901513       True

# %%
# Vamos reindexar o dataframe de Equivalencia pelo Código do TSE
df_equi_novo = df_equivalencia.copy()

df_equi_novo.set_index('COD_TSE', drop=False, inplace=True)

df_equi_novo.head()
# Out:
#                    chave          NOME  UF  GEOCOD_IBGE  COD_TSE AJUSTE
# COD_TSE
# 1120       ac acrelandia    ACRELÂNDIA  AC      1200013     1120    NaN
# 1570     ac assis brasil  ASSIS BRASIL  AC      1200054     1570    NaN
# 1058        ac brasileia     BRASILÉIA  AC      1200104     1058    NaN
# 1007           ac bujari        BUJARI  AC      1200138     1007    NaN
# 1015         ac capixaba      CAPIXABA  AC      1200179     1015    NaN

# %%
# Verificando o tamanho dos dataframes
df_vot_novo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 71072 to 90239
# Data columns (total 7 columns):
# SG_UF                5570 non-null object
# CD_MUNICIPIO         5570 non-null int64
# NM_MUNICIPIO         5570 non-null object
# NR_CANDIDATO         5570 non-null int64
# NM_URNA_CANDIDATO    5570 non-null object
# QT_VOTOS_NOMINAIS    5570 non-null int64
# RESULTADO            5570 non-null bool
# dtypes: bool(1), int64(3), object(3)
# memory usage: 310.0+ KB

# %%
df_equi_novo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 1120 to 96431
# Data columns (total 6 columns):
# chave          5570 non-null object
# NOME           5570 non-null object
# UF             5570 non-null object
# GEOCOD_IBGE    5570 non-null int64
# COD_TSE        5570 non-null int64
# AJUSTE         29 non-null object
# dtypes: int64(2), object(4)
# memory usage: 304.6+ KB

# %%
# Criando um novo dataframe com base no merge de Votação e Equivalencia
df_vot_equi = df_vot_novo.join(df_equi_novo)

df_vot_equi.head()
# Out:
#              SG_UF  CD_MUNICIPIO    NM_MUNICIPIO  NR_CANDIDATO  \
# CD_MUNICIPIO
# 71072           SP         71072       SÃO PAULO            17
# 60011           RJ         60011  RIO DE JANEIRO            17
# 97012           DF         97012        BRASÍLIA            17
# 38490           BA         38490        SALVADOR            13
# 41238           MG         41238  BELO HORIZONTE            17
#
#              NM_URNA_CANDIDATO  QT_VOTOS_NOMINAIS  RESULTADO  \
# CD_MUNICIPIO
# 71072           JAIR BOLSONARO            3694834       True
# 60011           JAIR BOLSONARO            2179896       True
# 97012           JAIR BOLSONARO            1080411       True
# 38490          FERNANDO HADDAD             985532      False
# 41238           JAIR BOLSONARO             901513       True
#
#                           chave            NOME  UF  GEOCOD_IBGE  COD_TSE  \
# CD_MUNICIPIO
# 71072              sp sao paulo       SÃO PAULO  SP      3550308    71072
# ...

# %%
# Vamos juntar o dataframe do GeoPandas com o dataframe Votação/Equivalência

df_vot_equi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 71072 to 90239
# Data columns (total 13 columns):
# SG_UF                5570 non-null object
# CD_MUNICIPIO         5570 non-null int64
# NM_MUNICIPIO         5570 non-null object
# NR_CANDIDATO         5570 non-null int64
# NM_URNA_CANDIDATO    5570 non-null object
# QT_VOTOS_NOMINAIS    5570 non-null int64
# RESULTADO            5570 non-null bool
# chave                5570 non-null object
# NOME                 5570 non-null object
# UF                   5570 non-null object
# GEOCOD_IBGE          5570 non-null int64
# COD_TSE              5570 non-null int64
# AJUSTE               29 non-null object
# dtypes: bool(1), int64(5), object(7)
# memory usage: 731.1+ KB

# %%
df_mapa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 3 columns):
# NM_MUNICIP    5572 non-null object
# CD_GEOCMU     5572 non-null object
# geometry      5572 non-null object
# dtypes: object(3)
# memory usage: 130.7+ KB

# %%
# Transformar a coluna de codigo de IBGE do dataframe de Votação/Equivalência
df_vot_equi['GEOCOD_IBGE'] = df_vot_equi['GEOCOD_IBGE'].astype(str)

df_vot_equi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5570 entries, 71072 to 90239
# Data columns (total 13 columns):
# SG_UF                5570 non-null object
# CD_MUNICIPIO         5570 non-null int64
# NM_MUNICIPIO         5570 non-null object
# NR_CANDIDATO         5570 non-null int64
# NM_URNA_CANDIDATO    5570 non-null object
# QT_VOTOS_NOMINAIS    5570 non-null int64
# RESULTADO            5570 non-null bool
# chave                5570 non-null object
# NOME                 5570 non-null object
# UF                   5570 non-null object
# GEOCOD_IBGE          5570 non-null object
# COD_TSE              5570 non-null int64
# AJUSTE               29 non-null object
# dtypes: bool(1), int64(4), object(8)
# memory usage: 731.1+ KB

# %%
# Vamos unificar os indices

# Mudando o indice do dataframe de Mapa
df_mapa.set_index('CD_GEOCMU', drop=False, inplace=True)

# %%
# Mudando o indice do dataframe de Votação/Equivalência
df_vot_equi.set_index('GEOCOD_IBGE', drop=False, inplace=True)

# %%
# Vamos juntar os dataframes
df_mapa_novo = df_mapa.join(df_vot_equi)

df_mapa_novo.head().T
# Out:
# CD_GEOCMU                                                    3509106  \
# NM_MUNICIP                                                    CAIUÃ
# CD_GEOCMU                                                    3509106
# geometry           POLYGON ((-51.86001052999998 -21.5807199056459...
# SG_UF                                                             SP
# CD_MUNICIPIO                                                   62839
# NM_MUNICIPIO                                                   CAIUÁ
# NR_CANDIDATO                                                      13
# NM_URNA_CANDIDATO                                    FERNANDO HADDAD
# QT_VOTOS_NOMINAIS                                               1320
# RESULTADO                                                      False
# chave                                                       sp caiua
# NOME                                                           CAIUÁ
# UF                                                                SP
# ...

# %%
# Verificando o tamanho do mapa novo
df_mapa_novo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 5572 entries, 3509106 to 1101807
# Data columns (total 16 columns):
# NM_MUNICIP           5572 non-null object
# CD_GEOCMU            5572 non-null object
# geometry             5572 non-null object
# SG_UF                5570 non-null object
# CD_MUNICIPIO         5570 non-null float64
# NM_MUNICIPIO         5570 non-null object
# NR_CANDIDATO         5570 non-null float64
# NM_URNA_CANDIDATO    5570 non-null object
# QT_VOTOS_NOMINAIS    5570 non-null float64
# RESULTADO            5570 non-null object
# chave                5570 non-null object
# NOME                 5570 non-null object
# UF                   5570 non-null object
# GEOCOD_IBGE          5570 non-null object
# COD_TSE              5570 non-null float64
# AJUSTE               29 non-null object
# dtypes: float64(4), object(12)
# memory usage: 900.0+ KB

# %%
# Vamos descobrir os 2 municipios a mais no mapa
df_mapa_novo[df_mapa_novo['NR_CANDIDATO'].isnull()]
# Out:
#                 NM_MUNICIP CD_GEOCMU  \
# CD_GEOCMU
# 4300001        LAGOA MIRIM   4300001
# 4300002    LAGOA DOS PATOS   4300002
#
#                                                     geometry SG_UF  \
# CD_GEOCMU
# 4300001    POLYGON ((-52.6224061101419 -32.14661509114978...   NaN
# 4300002    POLYGON ((-51.29028281599994 -30.0022243238175...   NaN
#
#            CD_MUNICIPIO NM_MUNICIPIO  NR_CANDIDATO NM_URNA_CANDIDATO  \
# CD_GEOCMU
# 4300001             NaN          NaN           NaN               NaN
# 4300002             NaN          NaN           NaN               NaN
#
#            QT_VOTOS_NOMINAIS RESULTADO chave NOME   UF GEOCOD_IBGE  COD_TSE  \
# CD_GEOCMU
# 4300001                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
# 4300002                  NaN       NaN   NaN  NaN  NaN         NaN      NaN
#
#           AJUSTE
# CD_GEOCMU
# 4300001      NaN
# 4300002      NaN

# %%
# Matar a coluna ajuste
df_mapa_novo.drop(columns=['AJUSTE'], inplace=True)

# %%
# Vamos eliminar a informação das duas lagoas do RS
df_mapa_novo.dropna(inplace=True)

# %%
df_mapa_novo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 5570 entries, 3509106 to 1101807
# Data columns (total 15 columns):
# NM_MUNICIP           5570 non-null object
# CD_GEOCMU            5570 non-null object
# geometry             5570 non-null object
# SG_UF                5570 non-null object
# CD_MUNICIPIO         5570 non-null float64
# NM_MUNICIPIO         5570 non-null object
# NR_CANDIDATO         5570 non-null float64
# NM_URNA_CANDIDATO    5570 non-null object
# QT_VOTOS_NOMINAIS    5570 non-null float64
# RESULTADO            5570 non-null object
# chave                5570 non-null object
# NOME                 5570 non-null object
# UF                   5570 non-null object
# GEOCOD_IBGE          5570 non-null object
# COD_TSE              5570 non-null float64
# dtypes: float64(4), object(11)
# memory usage: 696.2+ KB

# %%
# Vamos desenhar o mapa

# Criar a referência para o código de cor (False/0 = red, True/1 = green)
from matplotlib.colors import ListedColormap

cmap = ListedColormap(['#d6ee0f', '#47003d'])

# Desenhando o mapa
fig, ax = plt.subplots(1, figsize=(12, 12))

ax = df_mapa_novo.plot(column='RESULTADO', cmap=cmap, legend=True, linewidth=0.1, ax=ax,
                      edgecolor='grey')

# Escondendo o eixos
ax.set_axis_off()

# Colocando um título
ax.set_title('Resultado Eleição 2018 por Município / 2º Turno', fontdict={'fontsize': '25', 'fontweight': '3'})

# Criando uma nota do rodapé
ax.annotate('Fonte: IBGE, 2015; TSE, 2019; Jornal o Estado de São Paulo, 2019',
    xy=(0.1, 0.08), xycoords='figure fraction', horizontalalignment='left',
    verticalalignment='top', fontsize=10, color='#555555')

# Alterando a legenda
leg = ax.get_legend()
leg.get_texts()[0].set_text('')
leg.get_texts()[1].set_text('Comandante Moises')

plt.show()
